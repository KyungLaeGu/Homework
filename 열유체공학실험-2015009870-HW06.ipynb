# %% [markdown]
# <a href="https://colab.research.google.com/github/KyungLaeGu/Homework/blob/master/%EC%97%B4%EC%9C%A0%EC%B2%B4%EA%B3%B5%ED%95%99%EC%8B%A4%ED%97%98-2015009870-HW06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
* 감쇠진동 상미분방정식
 * 4x'' + 1x' + 4x = 0
 * x(0) = 10
 * x'(0) = 0
* 위와 같을 때 t = 0부터 t = 20까지의 위치를 그래프로 그리시오.
'''
import numpy as np
from scipy.linalg import * 
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

def dXdt( t, X ) :                              
    return  X[1], -0.25*X[1]-X[0]

# 초기값
X0 = ( 10, 0 ) 

t0 = 0
tend = 20

sol = solve_ivp( dXdt, (t0, tend), X0, t_eval=np.linspace(t0,tend,101) )
plt.plot( sol.t, sol.y[0] )
plt.xlabel('t')
plt.ylabel('y')
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/KyungLaeGu/Homework/blob/master/%EC%97%B4%EC%9C%A0%EC%B2%B4%EA%B3%B5%ED%95%99%EC%8B%A4%ED%97%98-2015009870-HW05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mpl_toolkits import mplot3d
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

def homework05():
    theta = 2 * np.pi * np.random.random(1000)
    r = 6 * np.random.random(1000)
    x = np.ravel(r * np.sin(theta))
    y = np.ravel(r * np.cos(theta))
    z = np.exp(-0.1*x**2-0.1*y**2)
    return x, y, z

x, y, z = homework05()

ax = plt.axes(projection='3d')
# TODO
# 아래 ax.plot_trisurf 함수 내부 인자를 완성하시오.
ax.plot_trisurf(x, y, z, cmap='binary');
ax.set_xlim(-5, 5); ax.set_ylim(-5, 5); ax.set_zlim(0, 1);
